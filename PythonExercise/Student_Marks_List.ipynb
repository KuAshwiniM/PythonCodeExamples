# %% [markdown]
# In Python, a list is a built-in, dynamic data structure used to store an ordered collection of items enclosed in square brackets [] and separated by commas. Lists are mutable, meaning you can modify, add, or remove items after the list is created.
# Key Characteristics
# Ordered: Items maintain their specific insertion order.
# Zero-Indexed: The first element starts at index 0.
# Mutable: Elements can change dynamically.
# Heterogeneous: Can store mixed data types like strings, integers, and booleans simultaneously.
# Allows Duplicates: Multiple elements can share identical values.

# %%
#create a list and print its contents
marks = [78, 85, 90, 67, 88, 92, 76]
print(type(marks))
print(marks)

#print first element of the list
print("First element:", marks[0])

#print last element of the list
print("Last element:", marks[-1])

#Print elements from index 2 to 5
print("Elements from index 2 to 5:", marks[2:6])
# Out:
# <class 'list'>
# [78, 85, 90, 67, 88, 92, 76]
# First element: 78
# Last element: 76
# Elements from index 2 to 5: [90, 67, 88, 92]

# %%
#Find the number of elements
length_marks = len(marks)
print("length of list is",length_marks)

#Find maximum marks
max_marks = max(marks)
print("maximum marks is",max_marks)

#Find minimum marks
min_marks = min(marks)
print("minimum marks is",min_marks)

#Find total marks
total_marks = sum(marks)
print("total marks is",total_marks)
# Out:
# length of list is 7
# maximum marks is 92
# minimum marks is 67
# total marks is 576

# %%
#ascending order
asc_marks = sorted(marks)
print("ascending order of marks is",asc_marks)

#descending order
desc_marks = sorted(marks, reverse=True)
print("descending order of marks is",desc_marks)
# Out:
# ascending order of marks is [67, 76, 78, 85, 88, 90, 92]
# descending order of marks is [92, 90, 88, 85, 78, 76, 67]

# %%
marks.append(95)
print("marks after adding new marks is",marks)

marks.append([81, 84])
print("marks after adding new list of marks is",marks)
# Out:
# marks after adding new marks is [78, 85, 90, 67, 88, 92, 76, 95]
# marks after adding new list of marks is [78, 85, 90, 67, 88, 92, 76, 95, [81, 84]]

# %%
marks.remove(67)
print("marks after removing 67 is",marks)

marks.count(90)
print("number of times 90 in list",marks.count(90))
# Out:
# marks after removing 67 is [78, 85, 90, 88, 92, 76, 95, [81, 84]]
# number of times 90 in list 1

# %%
print("index of 88 in list is", marks.index(88))
# Out:
# index of 88 in list is 3
