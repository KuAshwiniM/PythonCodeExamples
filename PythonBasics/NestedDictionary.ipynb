# %%
employee = {
"name": "Amit",
"department": "Engineering",
"skills": {
"language": "Python",
"database": "PostgreSQL",
"cloud": "AWS"
},
"salary": 80000
}
employee
# Out:
# {'name': 'Amit',
#  'department': 'Engineering',
#  'skills': {'language': 'Python', 'database': 'PostgreSQL', 'cloud': 'AWS'},
#  'salary': 80000}

# %%
#Print employee name
print(employee["name"])

#Print department
print(employee["department"])

#Print complete skills dictionary
print(employee["skills"])

#Print programming language
print(employee["skills"]["language"])

#Print database
print(employee["skills"]["database"])

#Print cloud technology
print(employee["skills"]["cloud"])
# Out:
# Amit
# Engineering
# {'language': 'Python', 'database': 'PostgreSQL', 'cloud': 'AWS'}
# Python
# PostgreSQL
# AWS

# %%
#Change "Python" to "Python + JavaScript"
employee["skills"]["language"] = "Python + JavaScript"
employee

#Change salary
employee["salary"] = 90000
employee
# Out:
# {'name': 'Amit',
#  'department': 'Engineering',
#  'skills': {'language': 'Python + JavaScript',
#   'database': 'PostgreSQL',
#   'cloud': 'AWS'},
#  'salary': 90000}

# %%
#Add "experience": 3
employee["experience"] = 3
employee
# Out:
# {'name': 'Amit',
#  'department': 'Engineering',
#  'skills': {'language': 'Python + JavaScript',
#   'database': 'PostgreSQL',
#   'cloud': 'AWS'},
#  'salary': 90000,
#  'experience': 3}

# %%
#Add another skill under the skills dictionary
employee["skills"]["framework"] = "Django"
employee
# Out:
# {'name': 'Amit',
#  'department': 'Engineering',
#  'skills': {'language': 'Python + JavaScript',
#   'database': 'PostgreSQL',
#   'cloud': 'AWS',
#   'framework': 'Django'},
#  'salary': 90000,
#  'experience': 3}

# %%
#Explain how nested dictionaries are accessed.
# Nested dictionaries are accessed by chaining the keys.
#  For example, employee["skills"]["language"] 
# accesses the programming language skill.
